# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_read = pd.read_csv("D:/deloitte/deloitte_assigmet_final/final_code/Logistic_Regression/assignment.csv")

# %%
df_read.isnull().sum()
# Out:
# content    4
# label      0
# dtype: int64

# %%
df_read.label.unique()
# Out:
# array(['Emotion', 'Financial', 'Politics', 'Sport', 'Health', 'Science'],
#       dtype=object)

# %%
df1 = df_read.label.value_counts()

# %%
df1
# Out:
# Politics     19202
# Health       18971
# Emotion      14641
# Financial    11746
# Sport         3073
# Science       2368
# Name: label, dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(df1.index,df1.values, color ='maroon', 
        width = 0.4)
 
plt.xlabel("Class Name",fontsize=16,color ="green")
plt.ylabel("No of data points in each class",fontsize=16,color ="green")
plt.title("Distribution of data points",fontsize=24,color ="blue")
plt.tick_params(labelsize=12)
plt.show()
